# %% [markdown]
# <a href="https://colab.research.google.com/github/polito-EAD-2026/colab/blob/dev/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install Librosa
# !pip install -q "librosa"
